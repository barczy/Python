# %%
import mlflow

# %%
mlflow.set_tracking_uri('http://127.0.0.1:5000/')
mlflow.set_experiment('Check localhost connection')
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1767957673634, experiment_id='1', last_update_time=1767957673634, lifecycle_stage='active', name='Check localhost connection', tags={}>

# %%
with mlflow.start_run():
    mlflow.log_metric('test3',1)
    mlflow.log_metric('Jack',2)
# Out:
# 🏃 View run gentle-whale-739 at: http://127.0.0.1:5000/#/experiments/1/runs/bf4924930b70401191187b41514c9ef3
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
